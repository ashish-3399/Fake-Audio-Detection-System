# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import librosa
import os
import math
import shutil
import pandas as pd

# %%
BASE_PATH = 'D:/coding projects/asvspoof2019/LA/LA'

# %%
train_df = pd.read_csv(f'{BASE_PATH}/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt',
                       sep=" ", header=None)

# %%
train_df.head(5)
# Out:
#          0             1  2  3         4
# 0  LA_0079  LA_T_1138215  -  -  bonafide
# 1  LA_0079  LA_T_1271820  -  -  bonafide
# 2  LA_0079  LA_T_1272637  -  -  bonafide
# 3  LA_0079  LA_T_1276960  -  -  bonafide
# 4  LA_0079  LA_T_1341447  -  -  bonafide

# %%
train_df.columns =['speaker_id','filename','system_id','class_name']
train_df.dropna(inplace=True)
train_df.head(5)
# Out:
#   speaker_id      filename system_id class_name
# 0    LA_0079  LA_T_1138215         -   bonafide
# 1    LA_0079  LA_T_1271820         -   bonafide
# 2    LA_0079  LA_T_1272637         -   bonafide
# 3    LA_0079  LA_T_1276960         -   bonafide
# 4    LA_0079  LA_T_1341447         -   bonafide

# %%
train_df['filepath'] = f'{BASE_PATH}/ASVspoof2019_LA_train/flac/'+train_df.filename+'.flac'
train_df['target'] = (train_df.class_name=='spoof').astype('int32')
print('len Train', len(train_df))
train_df.head(5)
# Out:
# len Train 25380
#   speaker_id      filename system_id class_name  \
# 0    LA_0079  LA_T_1138215         -   bonafide
# 1    LA_0079  LA_T_1271820         -   bonafide
# 2    LA_0079  LA_T_1272637         -   bonafide
# 3    LA_0079  LA_T_1276960         -   bonafide
# 4    LA_0079  LA_T_1341447         -   bonafide
#
#                                             filepath  target
# 0  D:/coding projects/asvspoof2019/LA/LA/ASVspoof...       0
# 1  D:/coding projects/asvspoof2019/LA/LA/ASVspoof...       0
# 2  D:/coding projects/asvspoof2019/LA/LA/ASVspoof...       0
# 3  D:/coding projects/asvspoof2019/LA/LA/ASVspoof...       0
# 4  D:/coding projects/asvspoof2019/LA/LA/ASVspoof...       0

# %%
import os
import shutil

# Check for pre-created folders and create them if necessary
output_folder_0 = './0'  # Folder name 0
output_folder_1 = './1'  # Folder name 1

if not os.path.exists(output_folder_0):
    os.makedirs(output_folder_0)

if not os.path.exists(output_folder_1):
    os.makedirs(output_folder_1)

# Train return the dataframe and copy the files to the corresponding folders
for index, row in train_df.iterrows():
    source_filepath = row['filepath']
    target_folder = f'./{row["target"]}'
    target_filepath = os.path.join(target_folder, os.path.basename(source_filepath))

    # Check the destination folder and create it if necessary
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    # Copy file to destination folder
    shutil.copy(source_filepath, target_filepath)

# You can use it to check the folders created after the process is complete
print(f'0 Folder {len(os.listdir(output_folder_0))} The file exists.')
print(f'1 Folder {len(os.listdir(output_folder_1))} The file exists.')
# Out:
# 0 Folder 2580 The file exists.
# 1 Folder 22800 The file exists.

# %%
folder_path = './0' 

files = os.listdir(folder_path)

total_files = len(files)

print(f"Total in folder {total_files} The file exists.")
# Out:
# Total in folder 2580 The file exists.

# %%
import os


folder_path = './1'  # The folder path you need to change

files = os.listdir(folder_path)

total_files = len(files)

print(f"Total in folder {total_files} The file exists.")
# Out:
# Total in folder 22800 The file exists.

# %%
import random

folder_path = './0'  # The folder path you need to change

files = os.listdir(folder_path)

total_files = len(files)

# Number of files to delete
num_files_to_delete = 1580

files_to_delete = random.sample(files, min(num_files_to_delete, total_files))

for file_name in files_to_delete:
    file_path = os.path.join(folder_path, file_name)
    try:
        os.remove(file_path)
        print(f"{file_name} file has been deleted.")
    except Exception as e:
        print(f"When deleting the error: {e}")

remaining_files = os.listdir(folder_path)
print(f"Total remaining in the folder {len(remaining_files)} The file exists.")
# Out:
# LA_T_9293135.flac file has been deleted.
# LA_T_4710044.flac file has been deleted.
# LA_T_8038233.flac file has been deleted.
# LA_T_4244329.flac file has been deleted.
# LA_T_4509152.flac file has been deleted.
# LA_T_9396899.flac file has been deleted.
# LA_T_5307856.flac file has been deleted.
# LA_T_8473215.flac file has been deleted.
# LA_T_5049541.flac file has been deleted.
# LA_T_9882639.flac file has been deleted.
# LA_T_5991300.flac file has been deleted.
# LA_T_3266022.flac file has been deleted.
# LA_T_3849267.flac file has been deleted.
# LA_T_8522600.flac file has been deleted.
# LA_T_9011341.flac file has been deleted.
# LA_T_8026644.flac file has been deleted.
# LA_T_1699801.flac file has been deleted.
# LA_T_1939177.flac file has been deleted.
# LA_T_5481932.flac file has been deleted.
# LA_T_2623490.flac file has been deleted.
# LA_T_3380327.flac file has been deleted.
# LA_T_6533322.flac file has been deleted.
# LA_T_7233209.flac file has been deleted.
# LA_T_5688847.flac file has been deleted.
# LA_T_4073132.flac file has been deleted.
# LA_T_9971213.flac file has been deleted.
# LA_T_1670486.flac file has been deleted.
# LA_T_3720724.flac file has been deleted.
# LA_T_9678657.flac file has been deleted.
# LA_T_8856169.flac file has been deleted.
# LA_T_4948515.flac file has been deleted.
# LA_T_7549713.flac file has been deleted.
# LA_T_3927701.flac file has been deleted.
# LA_T_3220828.flac file has been deleted.
# LA_T_6390530.flac file has been deleted.
# LA_T_9242200.flac file has been deleted.
# LA_T_3388956.flac file has been deleted.
# LA_T_7629056.flac file has been deleted.
# LA_T_1779188.flac file has been deleted.
# LA_T_9322055.flac file has been deleted.
# LA_T_8002835.flac file has been deleted.
# LA_T_6670899.flac file has been deleted.
# LA_T_6684256.flac file has been deleted.
# LA_T_2224597.flac file has been deleted.
# LA_T_6864430.flac file has been deleted.
# LA_T_8290600.flac file has been deleted.
# LA_T_6756969.flac file has been deleted.
# LA_T_6982603.flac file has been deleted.
# LA_T_8480400.flac file has been deleted.
# LA_T_2646474.flac file has been deleted.
# LA_T_8536928.flac file has been deleted.
# LA_T_7213473.flac file has been deleted.
# LA_T_8448396.flac file has been deleted.
# LA_T_4983711.flac file has been deleted.
# LA_T_3551277.flac file has been deleted.
# LA_T_2070410.flac file has been deleted.
# LA_T_3249684.flac file has been deleted.
# LA_T_1501005.flac file has been deleted.
# LA_T_1607779.flac file has been deleted.
# LA_T_9243374.flac file has been deleted.
# LA_T_3966049.flac file has been deleted.
# LA_T_9208716.flac file has been deleted.
# LA_T_4976230.flac file has been deleted.
# LA_T_2441274.flac file has been deleted.
# LA_T_6150466.flac file has been deleted.
# LA_T_4176612.flac file has been deleted.
# LA_T_1203360.flac file has been deleted.
# LA_T_6684559.flac file has been deleted.
# LA_T_9145540.flac file has been deleted.
# LA_T_1429012.flac file has been deleted.
# LA_T_9936219.flac file has been deleted.
# LA_T_6239874.flac file has been deleted.
# LA_T_6726155.flac file has been deleted.
# LA_T_7009144.flac file has been deleted.
# LA_T_7075102.flac file has been deleted.
# LA_T_6105178.flac file has been deleted.
# LA_T_2147641.flac file has been deleted.
# LA_T_8219979.flac file has been deleted.
# LA_T_6962044.flac file has been deleted.
# LA_T_3690594.flac file has been deleted.
# LA_T_1335486.flac file has been deleted.
# LA_T_8508520.flac file has been deleted.
# LA_T_4778437.flac file has been deleted.
# LA_T_7797285.flac file has been deleted.
# LA_T_5375232.flac file has been deleted.
# LA_T_5900964.flac file has been deleted.
# LA_T_2417641.flac file has been deleted.
# LA_T_5420024.flac file has been deleted.
# LA_T_2175978.flac file has been deleted.
# LA_T_4254409.flac file has been deleted.
# LA_T_2351250.flac file has been deleted.
# LA_T_9984182.flac file has been deleted.
# LA_T_3133284.flac file has been deleted.
# LA_T_6619199.flac file has been deleted.
# LA_T_1870772.flac file has been deleted.
# LA_T_6035510.flac file has been deleted.
# LA_T_6093418.flac file has been deleted.
# LA_T_6268937.flac file has been deleted.
# LA_T_5099625.flac file has been deleted.
# LA_T_6816405.flac file has been deleted.
# LA_T_4003689.flac file has been deleted.
# LA_T_6214695.flac file has been deleted.
# LA_T_1725860.flac file has been deleted.
# LA_T_5621967.flac file has been deleted.
# LA_T_2775248.flac file has been deleted.
# LA_T_6963013.flac file has been deleted.
# LA_T_9113475.flac file has been deleted.
# LA_T_2945120.flac file has been deleted.
# LA_T_1744427.flac file has been deleted.
# LA_T_4414920.flac file has been deleted.
# LA_T_5872172.flac file has been deleted.
# LA_T_4991041.flac file has been deleted.
# LA_T_4682842.flac file has been deleted.
# LA_T_5565624.flac file has been deleted.
# LA_T_7692745.flac file has been deleted.
# LA_T_8289751.flac file has been deleted.
# LA_T_4302417.flac file has been deleted.
# LA_T_7070241.flac file has been deleted.
# LA_T_1459453.flac file has been deleted.
# LA_T_2642748.flac file has been deleted.
# LA_T_1272637.flac file has been deleted.
# LA_T_6999716.flac file has been deleted.
# LA_T_6458679.flac file has been deleted.
# LA_T_5805796.flac file has been deleted.
# LA_T_5490265.flac file has been deleted.
# LA_T_9557645.flac file has been deleted.
# LA_T_3508808.flac file has been deleted.
# LA_T_2406356.flac file has been deleted.
# LA_T_7746591.flac file has been deleted.
# LA_T_3479921.flac file has been deleted.
# LA_T_3127213.flac file has been deleted.
# LA_T_3692595.flac file has been deleted.
# LA_T_1087973.flac file has been deleted.
# LA_T_7967427.flac file has been deleted.
# LA_T_4584120.flac file has been deleted.
# LA_T_2066209.flac file has been deleted.
# LA_T_3416785.flac file has been deleted.
# LA_T_7512717.flac file has been deleted.
# LA_T_7976744.flac file has been deleted.
# LA_T_8989127.flac file has been deleted.
# LA_T_5353096.flac file has been deleted.
# LA_T_1948575.flac file has been deleted.
# LA_T_9348273.flac file has been deleted.
# LA_T_4853464.flac file has been deleted.
# LA_T_4943154.flac file has been deleted.
# LA_T_6130907.flac file has been deleted.
# LA_T_3222760.flac file has been deleted.
# LA_T_5796504.flac file has been deleted.
# LA_T_8236638.flac file has been deleted.
# LA_T_2606704.flac file has been deleted.
# LA_T_9433144.flac file has been deleted.
# LA_T_2189446.flac file has been deleted.
# LA_T_2205687.flac file has been deleted.
# LA_T_4559826.flac file has been deleted.
# LA_T_8147741.flac file has been deleted.
# LA_T_9022965.flac file has been deleted.
# LA_T_9026573.flac file has been deleted.
# LA_T_9177970.flac file has been deleted.
# LA_T_8035781.flac file has been deleted.
# LA_T_1820456.flac file has been deleted.
# LA_T_4104820.flac file has been deleted.
# LA_T_4362109.flac file has been deleted.
# LA_T_5427607.flac file has been deleted.
# LA_T_3250855.flac file has been deleted.
# LA_T_5791737.flac file has been deleted.
# LA_T_2109303.flac file has been deleted.
# LA_T_4890539.flac file has been deleted.
# LA_T_7981442.flac file has been deleted.
# LA_T_4015268.flac file has been deleted.
# LA_T_6842563.flac file has been deleted.
# LA_T_6144753.flac file has been deleted.
# LA_T_8597023.flac file has been deleted.
# LA_T_9002298.flac file has been deleted.
# LA_T_8461963.flac file has been deleted.
# LA_T_3224558.flac file has been deleted.
# LA_T_1784012.flac file has been deleted.
# LA_T_4861861.flac file has been deleted.
# LA_T_1473061.flac file has been deleted.
# LA_T_4801937.flac file has been deleted.
# LA_T_5462809.flac file has been deleted.
# LA_T_7590799.flac file has been deleted.
# LA_T_9120168.flac file has been deleted.
# LA_T_9431341.flac file has been deleted.
# LA_T_3583591.flac file has been deleted.
# LA_T_9079590.flac file has been deleted.
# LA_T_8922157.flac file has been deleted.
# LA_T_5576506.flac file has been deleted.
# LA_T_5383824.flac file has been deleted.
# LA_T_8549038.flac file has been deleted.
# LA_T_3378774.flac file has been deleted.
# LA_T_4669930.flac file has been deleted.
# LA_T_7220833.flac file has been deleted.
# LA_T_7613910.flac file has been deleted.
# LA_T_3595333.flac file has been deleted.
# LA_T_5866595.flac file has been deleted.
# LA_T_5834325.flac file has been deleted.
# LA_T_5896323.flac file has been deleted.
# LA_T_6760264.flac file has been deleted.
# LA_T_4235900.flac file has been deleted.
# LA_T_6237013.flac file has been deleted.
# LA_T_1908512.flac file has been deleted.
# LA_T_2486958.flac file has been deleted.
# LA_T_1203196.flac file has been deleted.
# LA_T_9959600.flac file has been deleted.
# LA_T_3555171.flac file has been deleted.
# LA_T_6869854.flac file has been deleted.
# LA_T_8874328.flac file has been deleted.
# LA_T_3831892.flac file has been deleted.
# LA_T_1034923.flac file has been deleted.
# LA_T_4855131.flac file has been deleted.
# LA_T_6175341.flac file has been deleted.
# LA_T_2474244.flac file has been deleted.
# LA_T_3513521.flac file has been deleted.
# LA_T_9740938.flac file has been deleted.
# LA_T_2508565.flac file has been deleted.
# LA_T_8760655.flac file has been deleted.
# LA_T_7961517.flac file has been deleted.
# LA_T_1498247.flac file has been deleted.
# LA_T_6206040.flac file has been deleted.
# LA_T_5180830.flac file has been deleted.
# LA_T_6457872.flac file has been deleted.
# LA_T_5148524.flac file has been deleted.
# LA_T_6663907.flac file has been deleted.
# LA_T_6686104.flac file has been deleted.
# LA_T_7953369.flac file has been deleted.
# LA_T_2373806.flac file has been deleted.
# LA_T_6078773.flac file has been deleted.
# LA_T_5250310.flac file has been deleted.
# LA_T_4575102.flac file has been deleted.
# LA_T_1429555.flac file has been deleted.
# LA_T_1126222.flac file has been deleted.
# LA_T_6636159.flac file has been deleted.
# LA_T_9408141.flac file has been deleted.
# LA_T_5015893.flac file has been deleted.
# LA_T_3228820.flac file has been deleted.
# LA_T_5978032.flac file has been deleted.
# LA_T_2356349.flac file has been deleted.
# LA_T_7934464.flac file has been deleted.
# LA_T_1395369.flac file has been deleted.
# LA_T_4891748.flac file has been deleted.
# LA_T_9010570.flac file has been deleted.
# LA_T_4313462.flac file has been deleted.
# LA_T_8360330.flac file has been deleted.
# LA_T_5986630.flac file has been deleted.
# LA_T_8344139.flac file has been deleted.
# LA_T_2746439.flac file has been deleted.
# LA_T_4824196.flac file has been deleted.
# LA_T_7677120.flac file has been deleted.
# LA_T_4546797.flac file has been deleted.
# LA_T_4980224.flac file has been deleted.
# LA_T_9447463.flac file has been deleted.
# LA_T_9673436.flac file has been deleted.
# LA_T_9901878.flac file has been deleted.
# LA_T_3208992.flac file has been deleted.
# LA_T_5274567.flac file has been deleted.
# LA_T_6789290.flac file has been deleted.
# LA_T_4653938.flac file has been deleted.
# LA_T_5372373.flac file has been deleted.
# LA_T_7974459.flac file has been deleted.
# LA_T_9918657.flac file has been deleted.
# LA_T_3758429.flac file has been deleted.
# LA_T_7608685.flac file has been deleted.
# LA_T_1544986.flac file has been deleted.
# LA_T_6742582.flac file has been deleted.
# LA_T_6058143.flac file has been deleted.
# LA_T_9634249.flac file has been deleted.
# LA_T_7667225.flac file has been deleted.
# LA_T_9162137.flac file has been deleted.
# LA_T_2978319.flac file has been deleted.
# LA_T_6960204.flac file has been deleted.
# LA_T_1300559.flac file has been deleted.
# LA_T_4679163.flac file has been deleted.
# LA_T_3449995.flac file has been deleted.
# LA_T_3036128.flac file has been deleted.
# LA_T_4257400.flac file has been deleted.
# LA_T_7676958.flac file has been deleted.
# LA_T_9803720.flac file has been deleted.
# LA_T_9218626.flac file has been deleted.
# LA_T_1861398.flac file has been deleted.
# LA_T_9162513.flac file has been deleted.
# LA_T_9369156.flac file has been deleted.
# LA_T_5235221.flac file has been deleted.
# LA_T_7180834.flac file has been deleted.
# LA_T_1385311.flac file has been deleted.
# LA_T_3751646.flac file has been deleted.
# LA_T_1756992.flac file has been deleted.
# LA_T_4698044.flac file has been deleted.
# LA_T_4297429.flac file has been deleted.
# LA_T_9296432.flac file has been deleted.
# LA_T_3999087.flac file has been deleted.
# LA_T_3317496.flac file has been deleted.
# LA_T_9192060.flac file has been deleted.
# LA_T_2873890.flac file has been deleted.
# LA_T_8273340.flac file has been deleted.
# LA_T_8605065.flac file has been deleted.
# LA_T_5125810.flac file has been deleted.
# LA_T_9275052.flac file has been deleted.
# LA_T_2857301.flac file has been deleted.
# LA_T_9896961.flac file has been deleted.
# LA_T_5010828.flac file has been deleted.
# LA_T_1363611.flac file has been deleted.
# LA_T_6965985.flac file has been deleted.
# LA_T_8164024.flac file has been deleted.
# LA_T_3422948.flac file has been deleted.
# LA_T_2669204.flac file has been deleted.
# LA_T_7898068.flac file has been deleted.
# LA_T_4160149.flac file has been deleted.
# LA_T_5637214.flac file has been deleted.
# LA_T_5304944.flac file has been deleted.
# LA_T_3419879.flac file has been deleted.
# LA_T_6472478.flac file has been deleted.
# LA_T_7089329.flac file has been deleted.
# LA_T_2547007.flac file has been deleted.
# LA_T_3963452.flac file has been deleted.
# LA_T_6324553.flac file has been deleted.
# LA_T_7230726.flac file has been deleted.
# LA_T_1771704.flac file has been deleted.
# LA_T_7388260.flac file has been deleted.
# LA_T_1646336.flac file has been deleted.
# LA_T_8815396.flac file has been deleted.
# LA_T_7163377.flac file has been deleted.
# LA_T_5638559.flac file has been deleted.
# LA_T_5644159.flac file has been deleted.
# LA_T_7566470.flac file has been deleted.
# LA_T_3877061.flac file has been deleted.
# LA_T_2560396.flac file has been deleted.
# LA_T_1321385.flac file has been deleted.
# LA_T_9087690.flac file has been deleted.
# LA_T_9603308.flac file has been deleted.
# LA_T_6065241.flac file has been deleted.
# LA_T_1141342.flac file has been deleted.
# LA_T_2579587.flac file has been deleted.
# LA_T_2545938.flac file has been deleted.
# LA_T_1075302.flac file has been deleted.
# LA_T_3041149.flac file has been deleted.
# LA_T_4980341.flac file has been deleted.
# LA_T_5077870.flac file has been deleted.
# LA_T_7910229.flac file has been deleted.
# LA_T_3426509.flac file has been deleted.
# LA_T_3077492.flac file has been deleted.
# LA_T_5128913.flac file has been deleted.
# LA_T_7351960.flac file has been deleted.
# LA_T_6905979.flac file has been deleted.
# LA_T_4486316.flac file has been deleted.
# LA_T_3561136.flac file has been deleted.
# LA_T_6328130.flac file has been deleted.
# LA_T_1662243.flac file has been deleted.
# LA_T_7826803.flac file has been deleted.
# LA_T_8457102.flac file has been deleted.
# LA_T_6322780.flac file has been deleted.
# LA_T_9701712.flac file has been deleted.
# LA_T_5265204.flac file has been deleted.
# LA_T_4293504.flac file has been deleted.
# LA_T_4481879.flac file has been deleted.
# LA_T_5052270.flac file has been deleted.
# LA_T_4075500.flac file has been deleted.
# LA_T_2419538.flac file has been deleted.
# LA_T_9132181.flac file has been deleted.
# LA_T_6059767.flac file has been deleted.
# LA_T_7645220.flac file has been deleted.
# LA_T_9735807.flac file has been deleted.
# LA_T_3346004.flac file has been deleted.
# LA_T_5786461.flac file has been deleted.
# LA_T_5239258.flac file has been deleted.
# LA_T_9321757.flac file has been deleted.
# LA_T_8849210.flac file has been deleted.
# LA_T_9622854.flac file has been deleted.
# LA_T_3915181.flac file has been deleted.
# LA_T_6647814.flac file has been deleted.
# LA_T_5140325.flac file has been deleted.
# LA_T_1589744.flac file has been deleted.
# LA_T_5207966.flac file has been deleted.
# LA_T_2556562.flac file has been deleted.
# LA_T_6632904.flac file has been deleted.
# LA_T_2054424.flac file has been deleted.
# LA_T_8145267.flac file has been deleted.
# LA_T_3721939.flac file has been deleted.
# LA_T_4123333.flac file has been deleted.
# LA_T_7893747.flac file has been deleted.
# LA_T_7183032.flac file has been deleted.
# LA_T_4140258.flac file has been deleted.
# LA_T_9919874.flac file has been deleted.
# LA_T_6462285.flac file has been deleted.
# LA_T_5919047.flac file has been deleted.
# LA_T_1654106.flac file has been deleted.
# LA_T_9670904.flac file has been deleted.
# LA_T_9497115.flac file has been deleted.
# LA_T_3362906.flac file has been deleted.
# LA_T_8857843.flac file has been deleted.
# LA_T_2823943.flac file has been deleted.
# LA_T_4591528.flac file has been deleted.
# LA_T_1667973.flac file has been deleted.
# LA_T_4606578.flac file has been deleted.
# LA_T_8388870.flac file has been deleted.
# LA_T_8898922.flac file has been deleted.
# LA_T_6371068.flac file has been deleted.
# LA_T_7795139.flac file has been deleted.
# LA_T_4868237.flac file has been deleted.
# LA_T_4811800.flac file has been deleted.
# LA_T_6361429.flac file has been deleted.
# LA_T_3465801.flac file has been deleted.
# LA_T_4402006.flac file has been deleted.
# LA_T_9881753.flac file has been deleted.
# LA_T_1584182.flac file has been deleted.
# LA_T_9348735.flac file has been deleted.
# LA_T_3751912.flac file has been deleted.
# LA_T_4822766.flac file has been deleted.
# LA_T_1530054.flac file has been deleted.
# LA_T_1433631.flac file has been deleted.
# LA_T_2123366.flac file has been deleted.
# LA_T_1023546.flac file has been deleted.
# LA_T_2256140.flac file has been deleted.
# LA_T_8599305.flac file has been deleted.
# LA_T_2401614.flac file has been deleted.
# LA_T_6885448.flac file has been deleted.
# LA_T_5398911.flac file has been deleted.
# LA_T_8097695.flac file has been deleted.
# LA_T_1347550.flac file has been deleted.
# LA_T_5359998.flac file has been deleted.
# LA_T_8406833.flac file has been deleted.
# LA_T_3969759.flac file has been deleted.
# LA_T_7024437.flac file has been deleted.
# LA_T_2618051.flac file has been deleted.
# LA_T_1636563.flac file has been deleted.
# LA_T_4234865.flac file has been deleted.
# LA_T_8209686.flac file has been deleted.
# LA_T_6669331.flac file has been deleted.
# LA_T_7208401.flac file has been deleted.
# LA_T_8438885.flac file has been deleted.
# LA_T_6435787.flac file has been deleted.
# LA_T_2202862.flac file has been deleted.
# LA_T_8423394.flac file has been deleted.
# LA_T_7905464.flac file has been deleted.
# LA_T_5297168.flac file has been deleted.
# LA_T_2726428.flac file has been deleted.
# LA_T_6902662.flac file has been deleted.
# LA_T_6555022.flac file has been deleted.
# LA_T_8363647.flac file has been deleted.
# LA_T_3882719.flac file has been deleted.
# LA_T_6630946.flac file has been deleted.
# LA_T_8880498.flac file has been deleted.
# LA_T_9226005.flac file has been deleted.
# LA_T_3784759.flac file has been deleted.
# LA_T_6025945.flac file has been deleted.
# LA_T_1075018.flac file has been deleted.
# LA_T_5167256.flac file has been deleted.
# LA_T_9270440.flac file has been deleted.
# LA_T_1130943.flac file has been deleted.
# LA_T_7737217.flac file has been deleted.
# LA_T_9206457.flac file has been deleted.
# LA_T_8162147.flac file has been deleted.
# LA_T_6368265.flac file has been deleted.
# LA_T_1639691.flac file has been deleted.
# LA_T_8322635.flac file has been deleted.
# LA_T_8865587.flac file has been deleted.
# LA_T_7121055.flac file has been deleted.
# LA_T_1731260.flac file has been deleted.
# LA_T_8062147.flac file has been deleted.
# LA_T_3197072.flac file has been deleted.
# LA_T_3026804.flac file has been deleted.
# LA_T_6766056.flac file has been deleted.
# LA_T_9411327.flac file has been deleted.
# LA_T_2560383.flac file has been deleted.
# LA_T_3626619.flac file has been deleted.
# LA_T_5518956.flac file has been deleted.
# LA_T_8739453.flac file has been deleted.
# LA_T_8211262.flac file has been deleted.
# LA_T_6816591.flac file has been deleted.
# LA_T_6212732.flac file has been deleted.
# LA_T_7335715.flac file has been deleted.
# LA_T_7801452.flac file has been deleted.
# LA_T_7374710.flac file has been deleted.
# LA_T_6582371.flac file has been deleted.
# LA_T_5278239.flac file has been deleted.
# LA_T_5064135.flac file has been deleted.
# LA_T_8193150.flac file has been deleted.
# LA_T_8173514.flac file has been deleted.
# LA_T_2802903.flac file has been deleted.
# LA_T_5065316.flac file has been deleted.
# LA_T_2145141.flac file has been deleted.
# LA_T_7422329.flac file has been deleted.
# LA_T_4113721.flac file has been deleted.
# LA_T_4899172.flac file has been deleted.
# LA_T_1662696.flac file has been deleted.
# LA_T_8562513.flac file has been deleted.
# LA_T_1392484.flac file has been deleted.
# LA_T_2892203.flac file has been deleted.
# LA_T_5650122.flac file has been deleted.
# LA_T_4817040.flac file has been deleted.
# LA_T_8596867.flac file has been deleted.
# LA_T_2476165.flac file has been deleted.
# LA_T_9032022.flac file has been deleted.
# LA_T_5497895.flac file has been deleted.
# LA_T_1874118.flac file has been deleted.
# LA_T_5949193.flac file has been deleted.
# LA_T_1683467.flac file has been deleted.
# LA_T_2945445.flac file has been deleted.
# LA_T_6638771.flac file has been deleted.
# LA_T_9366701.flac file has been deleted.
# LA_T_6212674.flac file has been deleted.
# LA_T_1406603.flac file has been deleted.
# LA_T_1970201.flac file has been deleted.
# LA_T_5611078.flac file has been deleted.
# LA_T_1161711.flac file has been deleted.
# LA_T_3168858.flac file has been deleted.
# LA_T_3204342.flac file has been deleted.
# LA_T_4124430.flac file has been deleted.
# LA_T_6994918.flac file has been deleted.
# LA_T_3325414.flac file has been deleted.
# LA_T_4543133.flac file has been deleted.
# LA_T_9265598.flac file has been deleted.
# LA_T_3058432.flac file has been deleted.
# LA_T_3447323.flac file has been deleted.
# LA_T_7316655.flac file has been deleted.
# LA_T_3636245.flac file has been deleted.
# LA_T_3465911.flac file has been deleted.
# LA_T_9513704.flac file has been deleted.
# LA_T_2113561.flac file has been deleted.
# LA_T_2709262.flac file has been deleted.
# LA_T_8816234.flac file has been deleted.
# LA_T_6197882.flac file has been deleted.
# LA_T_1617431.flac file has been deleted.
# LA_T_3570279.flac file has been deleted.
# LA_T_8096613.flac file has been deleted.
# LA_T_4027900.flac file has been deleted.
# LA_T_2615390.flac file has been deleted.
# LA_T_8234497.flac file has been deleted.
# LA_T_6321801.flac file has been deleted.
# LA_T_6442486.flac file has been deleted.
# LA_T_2118892.flac file has been deleted.
# LA_T_6812855.flac file has been deleted.
# LA_T_9897034.flac file has been deleted.
# LA_T_5294797.flac file has been deleted.
# LA_T_3325988.flac file has been deleted.
# LA_T_3333905.flac file has been deleted.
# LA_T_1611587.flac file has been deleted.
# LA_T_1219386.flac file has been deleted.
# LA_T_6081492.flac file has been deleted.
# LA_T_6935436.flac file has been deleted.
# LA_T_4450108.flac file has been deleted.
# LA_T_5831523.flac file has been deleted.
# LA_T_9851949.flac file has been deleted.
# LA_T_3470152.flac file has been deleted.
# LA_T_7234844.flac file has been deleted.
# LA_T_5785306.flac file has been deleted.
# LA_T_6246443.flac file has been deleted.
# LA_T_7948400.flac file has been deleted.
# LA_T_8428155.flac file has been deleted.
# LA_T_2101210.flac file has been deleted.
# LA_T_7913619.flac file has been deleted.
# LA_T_8585150.flac file has been deleted.
# LA_T_1561484.flac file has been deleted.
# LA_T_7133372.flac file has been deleted.
# LA_T_8705208.flac file has been deleted.
# LA_T_1236840.flac file has been deleted.
# LA_T_1007663.flac file has been deleted.
# LA_T_5318441.flac file has been deleted.
# LA_T_6115632.flac file has been deleted.
# LA_T_2031287.flac file has been deleted.
# LA_T_7847845.flac file has been deleted.
# LA_T_3505871.flac file has been deleted.
# LA_T_7108923.flac file has been deleted.
# LA_T_1316001.flac file has been deleted.
# LA_T_1559861.flac file has been deleted.
# LA_T_8747294.flac file has been deleted.
# LA_T_1717556.flac file has been deleted.
# LA_T_9474664.flac file has been deleted.
# LA_T_3402710.flac file has been deleted.
# LA_T_7696598.flac file has been deleted.
# LA_T_3342439.flac file has been deleted.
# LA_T_7344886.flac file has been deleted.
# LA_T_3913974.flac file has been deleted.
# LA_T_7697985.flac file has been deleted.
# LA_T_8793633.flac file has been deleted.
# LA_T_5264471.flac file has been deleted.
# LA_T_6813958.flac file has been deleted.
# LA_T_3365001.flac file has been deleted.
# LA_T_6767811.flac file has been deleted.
# LA_T_2085766.flac file has been deleted.
# LA_T_7051313.flac file has been deleted.
# LA_T_8106288.flac file has been deleted.
# LA_T_1415351.flac file has been deleted.
# LA_T_9497800.flac file has been deleted.
# LA_T_3397728.flac file has been deleted.
# LA_T_4877664.flac file has been deleted.
# LA_T_5433418.flac file has been deleted.
# LA_T_8272787.flac file has been deleted.
# LA_T_6222543.flac file has been deleted.
# LA_T_1193043.flac file has been deleted.
# LA_T_9748392.flac file has been deleted.
# LA_T_4664105.flac file has been deleted.
# LA_T_5469120.flac file has been deleted.
# LA_T_4631069.flac file has been deleted.
# LA_T_2388783.flac file has been deleted.
# LA_T_7466998.flac file has been deleted.
# LA_T_5242457.flac file has been deleted.
# LA_T_1671516.flac file has been deleted.
# LA_T_9369650.flac file has been deleted.
# LA_T_5759484.flac file has been deleted.
# LA_T_2324368.flac file has been deleted.
# LA_T_6521045.flac file has been deleted.
# LA_T_6296859.flac file has been deleted.
# LA_T_1882969.flac file has been deleted.
# LA_T_9074196.flac file has been deleted.
# LA_T_8326490.flac file has been deleted.
# LA_T_5288751.flac file has been deleted.
# LA_T_8716901.flac file has been deleted.
# LA_T_7303315.flac file has been deleted.
# LA_T_5159753.flac file has been deleted.
# LA_T_3340235.flac file has been deleted.
# LA_T_4760367.flac file has been deleted.
# LA_T_6601259.flac file has been deleted.
# LA_T_3537526.flac file has been deleted.
# LA_T_2354787.flac file has been deleted.
# LA_T_6592806.flac file has been deleted.
# LA_T_5800430.flac file has been deleted.
# LA_T_1926066.flac file has been deleted.
# LA_T_7037373.flac file has been deleted.
# LA_T_5994708.flac file has been deleted.
# LA_T_3331468.flac file has been deleted.
# LA_T_2601192.flac file has been deleted.
# LA_T_2012289.flac file has been deleted.
# LA_T_1562164.flac file has been deleted.
# LA_T_2802034.flac file has been deleted.
# LA_T_7000444.flac file has been deleted.
# LA_T_6669635.flac file has been deleted.
# LA_T_1555189.flac file has been deleted.
# LA_T_3264613.flac file has been deleted.
# LA_T_4263726.flac file has been deleted.
# LA_T_4654973.flac file has been deleted.
# LA_T_1567067.flac file has been deleted.
# LA_T_8283217.flac file has been deleted.
# LA_T_4436477.flac file has been deleted.
# LA_T_6611269.flac file has been deleted.
# LA_T_9160184.flac file has been deleted.
# LA_T_6227496.flac file has been deleted.
# LA_T_4097500.flac file has been deleted.
# LA_T_2253051.flac file has been deleted.
# LA_T_2195795.flac file has been deleted.
# LA_T_5192765.flac file has been deleted.
# LA_T_9746491.flac file has been deleted.
# LA_T_2534170.flac file has been deleted.
# LA_T_9190599.flac file has been deleted.
# LA_T_1814008.flac file has been deleted.
# LA_T_8512706.flac file has been deleted.
# LA_T_4740742.flac file has been deleted.
# LA_T_3485288.flac file has been deleted.
# LA_T_6291192.flac file has been deleted.
# LA_T_5596732.flac file has been deleted.
# LA_T_6642565.flac file has been deleted.
# LA_T_8057044.flac file has been deleted.
# LA_T_9181464.flac file has been deleted.
# LA_T_3769139.flac file has been deleted.
# LA_T_3612681.flac file has been deleted.
# LA_T_7856471.flac file has been deleted.
# LA_T_2835258.flac file has been deleted.
# LA_T_6736628.flac file has been deleted.
# LA_T_2642014.flac file has been deleted.
# LA_T_8421122.flac file has been deleted.
# LA_T_5547883.flac file has been deleted.
# LA_T_3026599.flac file has been deleted.
# LA_T_5336219.flac file has been deleted.
# LA_T_3110916.flac file has been deleted.
# LA_T_1052790.flac file has been deleted.
# LA_T_6698994.flac file has been deleted.
# LA_T_4046944.flac file has been deleted.
# LA_T_5029038.flac file has been deleted.
# LA_T_7974354.flac file has been deleted.
# LA_T_3025335.flac file has been deleted.
# LA_T_8953087.flac file has been deleted.
# LA_T_7226623.flac file has been deleted.
# LA_T_3452222.flac file has been deleted.
# LA_T_8475651.flac file has been deleted.
# LA_T_3106270.flac file has been deleted.
# LA_T_2607307.flac file has been deleted.
# LA_T_5832791.flac file has been deleted.
# LA_T_3306464.flac file has been deleted.
# LA_T_4740750.flac file has been deleted.
# LA_T_4179989.flac file has been deleted.
# LA_T_6277993.flac file has been deleted.
# LA_T_6252972.flac file has been deleted.
# LA_T_8490370.flac file has been deleted.
# LA_T_4096254.flac file has been deleted.
# LA_T_5757722.flac file has been deleted.
# LA_T_8747878.flac file has been deleted.
# LA_T_5417170.flac file has been deleted.
# LA_T_6472152.flac file has been deleted.
# LA_T_9964017.flac file has been deleted.
# LA_T_9038660.flac file has been deleted.
# LA_T_9527200.flac file has been deleted.
# LA_T_4112194.flac file has been deleted.
# LA_T_3812469.flac file has been deleted.
# LA_T_1447757.flac file has been deleted.
# LA_T_3810183.flac file has been deleted.
# LA_T_7090581.flac file has been deleted.
# LA_T_1934754.flac file has been deleted.
# LA_T_5266787.flac file has been deleted.
# LA_T_3725307.flac file has been deleted.
# LA_T_1207505.flac file has been deleted.
# LA_T_7429069.flac file has been deleted.
# LA_T_6060006.flac file has been deleted.
# LA_T_3094730.flac file has been deleted.
# LA_T_7022615.flac file has been deleted.
# LA_T_1209325.flac file has been deleted.
# LA_T_2579773.flac file has been deleted.
# LA_T_7084634.flac file has been deleted.
# LA_T_2720806.flac file has been deleted.
# LA_T_9529868.flac file has been deleted.
# LA_T_1940419.flac file has been deleted.
# LA_T_9529079.flac file has been deleted.
# LA_T_7871766.flac file has been deleted.
# LA_T_6771766.flac file has been deleted.
# LA_T_8955767.flac file has been deleted.
# LA_T_4352298.flac file has been deleted.
# LA_T_7445288.flac file has been deleted.
# LA_T_7419838.flac file has been deleted.
# LA_T_8168811.flac file has been deleted.
# LA_T_2032733.flac file has been deleted.
# LA_T_6358737.flac file has been deleted.
# LA_T_6541095.flac file has been deleted.
# LA_T_9195565.flac file has been deleted.
# LA_T_6778841.flac file has been deleted.
# LA_T_5550327.flac file has been deleted.
# LA_T_1255705.flac file has been deleted.
# LA_T_6938738.flac file has been deleted.
# LA_T_4842455.flac file has been deleted.
# LA_T_1792767.flac file has been deleted.
# LA_T_7816568.flac file has been deleted.
# LA_T_7890801.flac file has been deleted.
# LA_T_3968554.flac file has been deleted.
# LA_T_3060760.flac file has been deleted.
# LA_T_4129008.flac file has been deleted.
# LA_T_4043474.flac file has been deleted.
# LA_T_1569381.flac file has been deleted.
# LA_T_1364415.flac file has been deleted.
# LA_T_5127288.flac file has been deleted.
# LA_T_5787857.flac file has been deleted.
# LA_T_2003699.flac file has been deleted.
# LA_T_6298599.flac file has been deleted.
# LA_T_1029184.flac file has been deleted.
# LA_T_5792324.flac file has been deleted.
# LA_T_2715624.flac file has been deleted.
# LA_T_6258131.flac file has been deleted.
# LA_T_6017121.flac file has been deleted.
# LA_T_6760364.flac file has been deleted.
# LA_T_8200308.flac file has been deleted.
# LA_T_3614268.flac file has been deleted.
# LA_T_7279842.flac file has been deleted.
# LA_T_3068473.flac file has been deleted.
# LA_T_3506909.flac file has been deleted.
# LA_T_2888246.flac file has been deleted.
# LA_T_1441999.flac file has been deleted.
# LA_T_5037374.flac file has been deleted.
# LA_T_7239632.flac file has been deleted.
# LA_T_7146737.flac file has been deleted.
# LA_T_1592972.flac file has been deleted.
# LA_T_7866363.flac file has been deleted.
# LA_T_8394081.flac file has been deleted.
# LA_T_6129228.flac file has been deleted.
# LA_T_7187958.flac file has been deleted.
# LA_T_1763423.flac file has been deleted.
# LA_T_6160841.flac file has been deleted.
# LA_T_9166813.flac file has been deleted.
# LA_T_6005929.flac file has been deleted.
# LA_T_1450124.flac file has been deleted.
# LA_T_4871078.flac file has been deleted.
# LA_T_3647140.flac file has been deleted.
# LA_T_8747149.flac file has been deleted.
# LA_T_2992916.flac file has been deleted.
# LA_T_5619335.flac file has been deleted.
# LA_T_6769763.flac file has been deleted.
# LA_T_2716529.flac file has been deleted.
# LA_T_1217514.flac file has been deleted.
# LA_T_5600038.flac file has been deleted.
# LA_T_8639914.flac file has been deleted.
# LA_T_8303411.flac file has been deleted.
# LA_T_8415843.flac file has been deleted.
# LA_T_9596913.flac file has been deleted.
# LA_T_1238061.flac file has been deleted.
# LA_T_9358107.flac file has been deleted.
# LA_T_5061172.flac file has been deleted.
# LA_T_6217520.flac file has been deleted.
# LA_T_8100988.flac file has been deleted.
# LA_T_7019947.flac file has been deleted.
# LA_T_1495856.flac file has been deleted.
# LA_T_9378967.flac file has been deleted.
# LA_T_8363686.flac file has been deleted.
# LA_T_9382795.flac file has been deleted.
# LA_T_7300523.flac file has been deleted.
# LA_T_9073024.flac file has been deleted.
# LA_T_3116625.flac file has been deleted.
# LA_T_4485359.flac file has been deleted.
# LA_T_7386069.flac file has been deleted.
# LA_T_9203438.flac file has been deleted.
# LA_T_6597785.flac file has been deleted.
# LA_T_5408992.flac file has been deleted.
# LA_T_3486820.flac file has been deleted.
# LA_T_6887491.flac file has been deleted.
# LA_T_8695539.flac file has been deleted.
# LA_T_7535350.flac file has been deleted.
# LA_T_6954528.flac file has been deleted.
# LA_T_3240252.flac file has been deleted.
# LA_T_3579841.flac file has been deleted.
# LA_T_8595870.flac file has been deleted.
# LA_T_9152126.flac file has been deleted.
# LA_T_1302542.flac file has been deleted.
# LA_T_4829875.flac file has been deleted.
# LA_T_3620571.flac file has been deleted.
# LA_T_1302075.flac file has been deleted.
# LA_T_8119863.flac file has been deleted.
# LA_T_5533183.flac file has been deleted.
# LA_T_7988057.flac file has been deleted.
# LA_T_3046012.flac file has been deleted.
# LA_T_4072277.flac file has been deleted.
# LA_T_1241016.flac file has been deleted.
# LA_T_6812192.flac file has been deleted.
# LA_T_5649093.flac file has been deleted.
# LA_T_9514965.flac file has been deleted.
# LA_T_6979533.flac file has been deleted.
# LA_T_1373249.flac file has been deleted.
# LA_T_4428776.flac file has been deleted.
# LA_T_6435392.flac file has been deleted.
# LA_T_4756464.flac file has been deleted.
# LA_T_6287491.flac file has been deleted.
# LA_T_8589988.flac file has been deleted.
# LA_T_6201923.flac file has been deleted.
# LA_T_6014366.flac file has been deleted.
# LA_T_3447201.flac file has been deleted.
# LA_T_5191549.flac file has been deleted.
# LA_T_6144368.flac file has been deleted.
# LA_T_3141223.flac file has been deleted.
# LA_T_1271820.flac file has been deleted.
# LA_T_1007571.flac file has been deleted.
# LA_T_2361518.flac file has been deleted.
# LA_T_5891808.flac file has been deleted.
# LA_T_6303319.flac file has been deleted.
# LA_T_1581753.flac file has been deleted.
# LA_T_4224058.flac file has been deleted.
# LA_T_2959505.flac file has been deleted.
# LA_T_7978694.flac file has been deleted.
# LA_T_1783185.flac file has been deleted.
# LA_T_7027346.flac file has been deleted.
# LA_T_7797083.flac file has been deleted.
# LA_T_4486346.flac file has been deleted.
# LA_T_7786868.flac file has been deleted.
# LA_T_7014336.flac file has been deleted.
# LA_T_6396662.flac file has been deleted.
# LA_T_3530627.flac file has been deleted.
# LA_T_1325059.flac file has been deleted.
# LA_T_1128865.flac file has been deleted.
# LA_T_1590800.flac file has been deleted.
# LA_T_1536675.flac file has been deleted.
# LA_T_8477522.flac file has been deleted.
# LA_T_8738028.flac file has been deleted.
# LA_T_3008265.flac file has been deleted.
# LA_T_8807017.flac file has been deleted.
# LA_T_4170168.flac file has been deleted.
# LA_T_4712212.flac file has been deleted.
# LA_T_4928920.flac file has been deleted.
# LA_T_6369221.flac file has been deleted.
# LA_T_2084171.flac file has been deleted.
# LA_T_3582106.flac file has been deleted.
# LA_T_3273877.flac file has been deleted.
# LA_T_4774940.flac file has been deleted.
# LA_T_6436385.flac file has been deleted.
# LA_T_4620749.flac file has been deleted.
# LA_T_1050008.flac file has been deleted.
# LA_T_6102672.flac file has been deleted.
# LA_T_5134869.flac file has been deleted.
# LA_T_7939231.flac file has been deleted.
# LA_T_9859327.flac file has been deleted.
# LA_T_9884044.flac file has been deleted.
# LA_T_1892730.flac file has been deleted.
# LA_T_4300434.flac file has been deleted.
# LA_T_3744808.flac file has been deleted.
# LA_T_2841157.flac file has been deleted.
# LA_T_5988636.flac file has been deleted.
# LA_T_6073470.flac file has been deleted.
# LA_T_7483904.flac file has been deleted.
# LA_T_1290428.flac file has been deleted.
# LA_T_4146672.flac file has been deleted.
# LA_T_5630619.flac file has been deleted.
# LA_T_6704810.flac file has been deleted.
# LA_T_5683238.flac file has been deleted.
# LA_T_5154755.flac file has been deleted.
# LA_T_1636151.flac file has been deleted.
# LA_T_6320963.flac file has been deleted.
# LA_T_4667091.flac file has been deleted.
# LA_T_8798465.flac file has been deleted.
# LA_T_4350005.flac file has been deleted.
# LA_T_4451463.flac file has been deleted.
# LA_T_9857249.flac file has been deleted.
# LA_T_6478161.flac file has been deleted.
# LA_T_9614820.flac file has been deleted.
# LA_T_3580508.flac file has been deleted.
# LA_T_6490007.flac file has been deleted.
# LA_T_4100536.flac file has been deleted.
# LA_T_2982213.flac file has been deleted.
# LA_T_3865653.flac file has been deleted.
# LA_T_7465137.flac file has been deleted.
# LA_T_3265392.flac file has been deleted.
# LA_T_1691318.flac file has been deleted.
# LA_T_4197307.flac file has been deleted.
# LA_T_3628518.flac file has been deleted.
# LA_T_7006038.flac file has been deleted.
# LA_T_8245483.flac file has been deleted.
# LA_T_2598851.flac file has been deleted.
# LA_T_3858431.flac file has been deleted.
# LA_T_9101277.flac file has been deleted.
# LA_T_9609293.flac file has been deleted.
# LA_T_6413988.flac file has been deleted.
# LA_T_7140181.flac file has been deleted.
# LA_T_8305834.flac file has been deleted.
# LA_T_4900136.flac file has been deleted.
# LA_T_7807441.flac file has been deleted.
# LA_T_8811170.flac file has been deleted.
# LA_T_1678844.flac file has been deleted.
# LA_T_8220892.flac file has been deleted.
# LA_T_7521161.flac file has been deleted.
# LA_T_3105506.flac file has been deleted.
# LA_T_1504888.flac file has been deleted.
# LA_T_2207320.flac file has been deleted.
# LA_T_1573354.flac file has been deleted.
# LA_T_1787169.flac file has been deleted.
# LA_T_8105444.flac file has been deleted.
# LA_T_9905136.flac file has been deleted.
# LA_T_6746965.flac file has been deleted.
# LA_T_7337587.flac file has been deleted.
# LA_T_9804482.flac file has been deleted.
# LA_T_6093991.flac file has been deleted.
# LA_T_3376738.flac file has been deleted.
# LA_T_2535749.flac file has been deleted.
# LA_T_1487560.flac file has been deleted.
# LA_T_9480695.flac file has been deleted.
# LA_T_3163425.flac file has been deleted.
# LA_T_9689088.flac file has been deleted.
# LA_T_9854823.flac file has been deleted.
# LA_T_5100132.flac file has been deleted.
# LA_T_8543558.flac file has been deleted.
# LA_T_2542674.flac file has been deleted.
# LA_T_2100932.flac file has been deleted.
# LA_T_8438461.flac file has been deleted.
# LA_T_7086580.flac file has been deleted.
# LA_T_3058443.flac file has been deleted.
# LA_T_3244166.flac file has been deleted.
# LA_T_6292792.flac file has been deleted.
# LA_T_1477639.flac file has been deleted.
# LA_T_2579152.flac file has been deleted.
# LA_T_1561078.flac file has been deleted.
# LA_T_5984686.flac file has been deleted.
# LA_T_2019805.flac file has been deleted.
# LA_T_6725057.flac file has been deleted.
# LA_T_1052701.flac file has been deleted.
# LA_T_2993376.flac file has been deleted.
# LA_T_3288573.flac file has been deleted.
# LA_T_7877019.flac file has been deleted.
# LA_T_2193944.flac file has been deleted.
# LA_T_5337549.flac file has been deleted.
# LA_T_2634789.flac file has been deleted.
# LA_T_4030250.flac file has been deleted.
# LA_T_4940666.flac file has been deleted.
# LA_T_7123800.flac file has been deleted.
# LA_T_2901163.flac file has been deleted.
# LA_T_8593946.flac file has been deleted.
# LA_T_2347217.flac file has been deleted.
# LA_T_3707104.flac file has been deleted.
# LA_T_8830400.flac file has been deleted.
# LA_T_7302615.flac file has been deleted.
# LA_T_6688612.flac file has been deleted.
# LA_T_9043274.flac file has been deleted.
# LA_T_2176518.flac file has been deleted.
# LA_T_8814910.flac file has been deleted.
# LA_T_1745865.flac file has been deleted.
# LA_T_4387428.flac file has been deleted.
# LA_T_9951511.flac file has been deleted.
# LA_T_4366892.flac file has been deleted.
# LA_T_3492130.flac file has been deleted.
# LA_T_6290647.flac file has been deleted.
# LA_T_8464594.flac file has been deleted.
# LA_T_2217523.flac file has been deleted.
# LA_T_1021790.flac file has been deleted.
# LA_T_5404480.flac file has been deleted.
# LA_T_4621617.flac file has been deleted.
# LA_T_4357296.flac file has been deleted.
# LA_T_2555028.flac file has been deleted.
# LA_T_6927292.flac file has been deleted.
# LA_T_7478780.flac file has been deleted.
# LA_T_9667089.flac file has been deleted.
# LA_T_2598025.flac file has been deleted.
# LA_T_8156237.flac file has been deleted.
# LA_T_7698485.flac file has been deleted.
# LA_T_7972168.flac file has been deleted.
# LA_T_2783139.flac file has been deleted.
# LA_T_6720241.flac file has been deleted.
# LA_T_8405652.flac file has been deleted.
# LA_T_1341447.flac file has been deleted.
# LA_T_8459875.flac file has been deleted.
# LA_T_7027837.flac file has been deleted.
# LA_T_7015765.flac file has been deleted.
# LA_T_6496177.flac file has been deleted.
# LA_T_5616380.flac file has been deleted.
# LA_T_5208337.flac file has been deleted.
# LA_T_8925615.flac file has been deleted.
# LA_T_4197596.flac file has been deleted.
# LA_T_9543922.flac file has been deleted.
# LA_T_1831818.flac file has been deleted.
# LA_T_3176879.flac file has been deleted.
# LA_T_1684951.flac file has been deleted.
# LA_T_7165182.flac file has been deleted.
# LA_T_2829414.flac file has been deleted.
# LA_T_1091653.flac file has been deleted.
# LA_T_9789409.flac file has been deleted.
# LA_T_8988036.flac file has been deleted.
# LA_T_3477694.flac file has been deleted.
# LA_T_4511853.flac file has been deleted.
# LA_T_8176264.flac file has been deleted.
# LA_T_8171933.flac file has been deleted.
# LA_T_8127151.flac file has been deleted.
# LA_T_4092827.flac file has been deleted.
# LA_T_3679258.flac file has been deleted.
# LA_T_5774498.flac file has been deleted.
# LA_T_5585550.flac file has been deleted.
# LA_T_5340625.flac file has been deleted.
# LA_T_3772667.flac file has been deleted.
# LA_T_6049368.flac file has been deleted.
# LA_T_2684786.flac file has been deleted.
# LA_T_5410799.flac file has been deleted.
# LA_T_7024695.flac file has been deleted.
# LA_T_1041717.flac file has been deleted.
# LA_T_4369129.flac file has been deleted.
# LA_T_2698001.flac file has been deleted.
# LA_T_6627080.flac file has been deleted.
# LA_T_4464373.flac file has been deleted.
# LA_T_2720285.flac file has been deleted.
# LA_T_1897788.flac file has been deleted.
# LA_T_5846701.flac file has been deleted.
# LA_T_7848595.flac file has been deleted.
# LA_T_2280500.flac file has been deleted.
# LA_T_8751424.flac file has been deleted.
# LA_T_3159022.flac file has been deleted.
# LA_T_1423202.flac file has been deleted.
# LA_T_3383878.flac file has been deleted.
# LA_T_3525725.flac file has been deleted.
# LA_T_8702524.flac file has been deleted.
# LA_T_9341221.flac file has been deleted.
# LA_T_8707487.flac file has been deleted.
# LA_T_5937046.flac file has been deleted.
# LA_T_8185303.flac file has been deleted.
# LA_T_9762480.flac file has been deleted.
# LA_T_1158098.flac file has been deleted.
# LA_T_9741234.flac file has been deleted.
# LA_T_1698724.flac file has been deleted.
# LA_T_7509819.flac file has been deleted.
# LA_T_1543826.flac file has been deleted.
# LA_T_7065043.flac file has been deleted.
# LA_T_2582808.flac file has been deleted.
# LA_T_7544663.flac file has been deleted.
# LA_T_2507189.flac file has been deleted.
# LA_T_4406929.flac file has been deleted.
# LA_T_6627269.flac file has been deleted.
# LA_T_5520907.flac file has been deleted.
# LA_T_2774050.flac file has been deleted.
# LA_T_4707993.flac file has been deleted.
# LA_T_3683196.flac file has been deleted.
# LA_T_3215578.flac file has been deleted.
# LA_T_1013597.flac file has been deleted.
# LA_T_6343266.flac file has been deleted.
# LA_T_8169980.flac file has been deleted.
# LA_T_6499650.flac file has been deleted.
# LA_T_3659915.flac file has been deleted.
# LA_T_7717952.flac file has been deleted.
# LA_T_3888223.flac file has been deleted.
# LA_T_9976341.flac file has been deleted.
# LA_T_6741908.flac file has been deleted.
# LA_T_8189651.flac file has been deleted.
# LA_T_2682425.flac file has been deleted.
# LA_T_8196808.flac file has been deleted.
# LA_T_5610586.flac file has been deleted.
# LA_T_9132666.flac file has been deleted.
# LA_T_8533509.flac file has been deleted.
# LA_T_7220961.flac file has been deleted.
# LA_T_1963829.flac file has been deleted.
# LA_T_6553669.flac file has been deleted.
# LA_T_5235055.flac file has been deleted.
# LA_T_7034456.flac file has been deleted.
# LA_T_4971377.flac file has been deleted.
# LA_T_3070659.flac file has been deleted.
# LA_T_6658542.flac file has been deleted.
# LA_T_9717737.flac file has been deleted.
# LA_T_5458231.flac file has been deleted.
# LA_T_7217038.flac file has been deleted.
# LA_T_8052308.flac file has been deleted.
# LA_T_3310939.flac file has been deleted.
# LA_T_9803057.flac file has been deleted.
# LA_T_7776350.flac file has been deleted.
# LA_T_6474634.flac file has been deleted.
# LA_T_6476075.flac file has been deleted.
# LA_T_3515602.flac file has been deleted.
# LA_T_2737588.flac file has been deleted.
# LA_T_9730601.flac file has been deleted.
# LA_T_9860699.flac file has been deleted.
# LA_T_7397041.flac file has been deleted.
# LA_T_8419713.flac file has been deleted.
# LA_T_2079451.flac file has been deleted.
# LA_T_8430551.flac file has been deleted.
# LA_T_6651761.flac file has been deleted.
# LA_T_6952169.flac file has been deleted.
# LA_T_9074017.flac file has been deleted.
# LA_T_8214917.flac file has been deleted.
# LA_T_8927591.flac file has been deleted.
# LA_T_8342357.flac file has been deleted.
# LA_T_5079307.flac file has been deleted.
# LA_T_3904040.flac file has been deleted.
# LA_T_8566553.flac file has been deleted.
# LA_T_9896606.flac file has been deleted.
# LA_T_2454697.flac file has been deleted.
# LA_T_2482961.flac file has been deleted.
# LA_T_3884115.flac file has been deleted.
# LA_T_3925776.flac file has been deleted.
# LA_T_4400578.flac file has been deleted.
# LA_T_5132134.flac file has been deleted.
# LA_T_9838989.flac file has been deleted.
# LA_T_6993201.flac file has been deleted.
# LA_T_6117487.flac file has been deleted.
# LA_T_6551574.flac file has been deleted.
# LA_T_9444221.flac file has been deleted.
# LA_T_4292472.flac file has been deleted.
# LA_T_6240107.flac file has been deleted.
# LA_T_6869508.flac file has been deleted.
# LA_T_7292672.flac file has been deleted.
# LA_T_2092466.flac file has been deleted.
# LA_T_1078395.flac file has been deleted.
# LA_T_4298489.flac file has been deleted.
# LA_T_4557107.flac file has been deleted.
# LA_T_5034418.flac file has been deleted.
# LA_T_4829102.flac file has been deleted.
# LA_T_2707835.flac file has been deleted.
# LA_T_1369507.flac file has been deleted.
# LA_T_6710807.flac file has been deleted.
# LA_T_2216602.flac file has been deleted.
# LA_T_3730329.flac file has been deleted.
# LA_T_6541032.flac file has been deleted.
# LA_T_6192370.flac file has been deleted.
# LA_T_1721632.flac file has been deleted.
# LA_T_5544402.flac file has been deleted.
# LA_T_7833340.flac file has been deleted.
# LA_T_5249142.flac file has been deleted.
# LA_T_8503822.flac file has been deleted.
# LA_T_1821843.flac file has been deleted.
# LA_T_4057520.flac file has been deleted.
# LA_T_1773196.flac file has been deleted.
# LA_T_2202252.flac file has been deleted.
# LA_T_6354141.flac file has been deleted.
# LA_T_9874922.flac file has been deleted.
# LA_T_2580639.flac file has been deleted.
# LA_T_4825294.flac file has been deleted.
# LA_T_5264330.flac file has been deleted.
# LA_T_8884269.flac file has been deleted.
# LA_T_8025784.flac file has been deleted.
# LA_T_3041626.flac file has been deleted.
# LA_T_7630574.flac file has been deleted.
# LA_T_7865475.flac file has been deleted.
# LA_T_4711197.flac file has been deleted.
# LA_T_2043279.flac file has been deleted.
# LA_T_6804590.flac file has been deleted.
# LA_T_4348949.flac file has been deleted.
# LA_T_4901591.flac file has been deleted.
# LA_T_5065822.flac file has been deleted.
# LA_T_9759753.flac file has been deleted.
# LA_T_1933336.flac file has been deleted.
# ...
# LA_T_3121388.flac file has been deleted.
# LA_T_5364220.flac file has been deleted.
# LA_T_2869730.flac file has been deleted.
# LA_T_9219481.flac file has been deleted.
# LA_T_3560086.flac file has been deleted.
# LA_T_2376874.flac file has been deleted.
# LA_T_1000406.flac file has been deleted.
# LA_T_3455098.flac file has been deleted.
# LA_T_8714194.flac file has been deleted.
# LA_T_9711208.flac file has been deleted.
# LA_T_1864383.flac file has been deleted.
# LA_T_9482402.flac file has been deleted.
# LA_T_1740931.flac file has been deleted.
# LA_T_8337767.flac file has been deleted.
# LA_T_8265782.flac file has been deleted.
# LA_T_1208112.flac file has been deleted.
# LA_T_2699884.flac file has been deleted.
# LA_T_6727856.flac file has been deleted.
# LA_T_1590181.flac file has been deleted.
# LA_T_6388012.flac file has been deleted.
# LA_T_8647496.flac file has been deleted.
# LA_T_2759900.flac file has been deleted.
# LA_T_4130056.flac file has been deleted.
# LA_T_8847275.flac file has been deleted.
# LA_T_2948101.flac file has been deleted.
# LA_T_2747022.flac file has been deleted.
# LA_T_6441166.flac file has been deleted.
# LA_T_7846284.flac file has been deleted.
# LA_T_4566714.flac file has been deleted.
# LA_T_9392152.flac file has been deleted.
# LA_T_7939465.flac file has been deleted.
# LA_T_8971754.flac file has been deleted.
# LA_T_7152560.flac file has been deleted.
# LA_T_8502808.flac file has been deleted.
# LA_T_8371319.flac file has been deleted.
# LA_T_2297014.flac file has been deleted.
# LA_T_7740663.flac file has been deleted.
# LA_T_4657133.flac file has been deleted.
# LA_T_7779179.flac file has been deleted.
# LA_T_4290789.flac file has been deleted.
# LA_T_3707386.flac file has been deleted.
# LA_T_9351820.flac file has been deleted.
# LA_T_5696560.flac file has been deleted.
# LA_T_7785251.flac file has been deleted.
# LA_T_1235793.flac file has been deleted.
# LA_T_4051929.flac file has been deleted.
# LA_T_9660280.flac file has been deleted.
# LA_T_4891261.flac file has been deleted.
# LA_T_7144134.flac file has been deleted.
# LA_T_9508827.flac file has been deleted.
# LA_T_9226313.flac file has been deleted.
# LA_T_8162915.flac file has been deleted.
# LA_T_4171687.flac file has been deleted.
# LA_T_7533042.flac file has been deleted.
# LA_T_3812400.flac file has been deleted.
# LA_T_7450091.flac file has been deleted.
# LA_T_2732709.flac file has been deleted.
# LA_T_1284700.flac file has been deleted.
# LA_T_3686789.flac file has been deleted.
# LA_T_5554253.flac file has been deleted.
# LA_T_2528047.flac file has been deleted.
# LA_T_1651877.flac file has been deleted.
# LA_T_5463606.flac file has been deleted.
# LA_T_3843638.flac file has been deleted.
# LA_T_3050170.flac file has been deleted.
# LA_T_7890455.flac file has been deleted.
# LA_T_8758984.flac file has been deleted.
# LA_T_8864733.flac file has been deleted.
# LA_T_6615690.flac file has been deleted.
# LA_T_9188299.flac file has been deleted.
# LA_T_1511191.flac file has been deleted.
# LA_T_4300273.flac file has been deleted.
# LA_T_9536026.flac file has been deleted.
# LA_T_8420146.flac file has been deleted.
# LA_T_2386039.flac file has been deleted.
# LA_T_8511040.flac file has been deleted.
# LA_T_5223695.flac file has been deleted.
# LA_T_8285892.flac file has been deleted.
# LA_T_7402461.flac file has been deleted.
# LA_T_8324598.flac file has been deleted.
# LA_T_3958101.flac file has been deleted.
# LA_T_1269462.flac file has been deleted.
# LA_T_4077869.flac file has been deleted.
# LA_T_2815613.flac file has been deleted.
# LA_T_2801814.flac file has been deleted.
# LA_T_8458654.flac file has been deleted.
# LA_T_3729389.flac file has been deleted.
# LA_T_5824253.flac file has been deleted.
# LA_T_4898635.flac file has been deleted.
# LA_T_5570263.flac file has been deleted.
# LA_T_9273556.flac file has been deleted.
# LA_T_6992885.flac file has been deleted.
# LA_T_7645518.flac file has been deleted.
# LA_T_8683008.flac file has been deleted.
# LA_T_8321337.flac file has been deleted.
# LA_T_5481571.flac file has been deleted.
# LA_T_4365712.flac file has been deleted.
# LA_T_8919107.flac file has been deleted.
# LA_T_4196090.flac file has been deleted.
# LA_T_9749112.flac file has been deleted.
# LA_T_4614402.flac file has been deleted.
# LA_T_8107610.flac file has been deleted.
# LA_T_2857315.flac file has been deleted.
# LA_T_6442639.flac file has been deleted.
# LA_T_1160090.flac file has been deleted.
# LA_T_5891775.flac file has been deleted.
# LA_T_7985597.flac file has been deleted.
# LA_T_5387852.flac file has been deleted.
# LA_T_3860059.flac file has been deleted.
# LA_T_3576775.flac file has been deleted.
# LA_T_6795804.flac file has been deleted.
# LA_T_1457379.flac file has been deleted.
# LA_T_9126862.flac file has been deleted.
# LA_T_6298658.flac file has been deleted.
# LA_T_1011221.flac file has been deleted.
# LA_T_2267510.flac file has been deleted.
# LA_T_8686549.flac file has been deleted.
# LA_T_2807421.flac file has been deleted.
# LA_T_1276415.flac file has been deleted.
# LA_T_2504535.flac file has been deleted.
# LA_T_7943455.flac file has been deleted.
# LA_T_3197627.flac file has been deleted.
# LA_T_7462273.flac file has been deleted.
# LA_T_1735385.flac file has been deleted.
# LA_T_8665775.flac file has been deleted.
# LA_T_7990660.flac file has been deleted.
# LA_T_6780253.flac file has been deleted.
# LA_T_9229570.flac file has been deleted.
# LA_T_2532093.flac file has been deleted.
# LA_T_4966921.flac file has been deleted.
# LA_T_7039518.flac file has been deleted.
# LA_T_5712226.flac file has been deleted.
# LA_T_2065195.flac file has been deleted.
# LA_T_6253524.flac file has been deleted.
# LA_T_2307815.flac file has been deleted.
# LA_T_4105004.flac file has been deleted.
# LA_T_9772981.flac file has been deleted.
# LA_T_9644311.flac file has been deleted.
# LA_T_5751244.flac file has been deleted.
# LA_T_7607573.flac file has been deleted.
# LA_T_7720305.flac file has been deleted.
# LA_T_4807785.flac file has been deleted.
# LA_T_7958352.flac file has been deleted.
# LA_T_6271185.flac file has been deleted.
# LA_T_1186717.flac file has been deleted.
# LA_T_4674925.flac file has been deleted.
# LA_T_7597238.flac file has been deleted.
# LA_T_3324636.flac file has been deleted.
# LA_T_3661578.flac file has been deleted.
# LA_T_7500588.flac file has been deleted.
# LA_T_1591810.flac file has been deleted.
# LA_T_3487529.flac file has been deleted.
# LA_T_1470659.flac file has been deleted.
# LA_T_9502120.flac file has been deleted.
# LA_T_3163159.flac file has been deleted.
# LA_T_1406835.flac file has been deleted.
# LA_T_2866777.flac file has been deleted.
# LA_T_6949400.flac file has been deleted.
# LA_T_9745018.flac file has been deleted.
# LA_T_9324386.flac file has been deleted.
# LA_T_8093170.flac file has been deleted.
# LA_T_9884197.flac file has been deleted.
# LA_T_8947818.flac file has been deleted.
# LA_T_2804125.flac file has been deleted.
# LA_T_3538502.flac file has been deleted.
# LA_T_2903988.flac file has been deleted.
# LA_T_9912406.flac file has been deleted.
# LA_T_6505103.flac file has been deleted.
# LA_T_4006888.flac file has been deleted.
# LA_T_2129069.flac file has been deleted.
# LA_T_2158689.flac file has been deleted.
# LA_T_2033687.flac file has been deleted.
# LA_T_6756379.flac file has been deleted.
# LA_T_3108269.flac file has been deleted.
# LA_T_5656982.flac file has been deleted.
# LA_T_4615273.flac file has been deleted.
# LA_T_8812445.flac file has been deleted.
# LA_T_1644078.flac file has been deleted.
# LA_T_5463262.flac file has been deleted.
# LA_T_6306026.flac file has been deleted.
# LA_T_6856715.flac file has been deleted.
# LA_T_9654665.flac file has been deleted.
# LA_T_1379329.flac file has been deleted.
# LA_T_9213454.flac file has been deleted.
# LA_T_9671043.flac file has been deleted.
# LA_T_3524074.flac file has been deleted.
# LA_T_9754081.flac file has been deleted.
# LA_T_2866573.flac file has been deleted.
# LA_T_6078217.flac file has been deleted.
# LA_T_7753868.flac file has been deleted.
# LA_T_7974410.flac file has been deleted.
# LA_T_4403320.flac file has been deleted.
# LA_T_4246466.flac file has been deleted.
# LA_T_1407047.flac file has been deleted.
# LA_T_5280384.flac file has been deleted.
# LA_T_5973899.flac file has been deleted.
# LA_T_9257520.flac file has been deleted.
# LA_T_1749681.flac file has been deleted.
# LA_T_4752788.flac file has been deleted.
# LA_T_1397401.flac file has been deleted.
# LA_T_8621866.flac file has been deleted.
# LA_T_6423802.flac file has been deleted.
# LA_T_5051764.flac file has been deleted.
# LA_T_3030505.flac file has been deleted.
# LA_T_6858471.flac file has been deleted.
# LA_T_3104100.flac file has been deleted.
# LA_T_2797155.flac file has been deleted.
# LA_T_7310231.flac file has been deleted.
# LA_T_7358237.flac file has been deleted.
# LA_T_9223743.flac file has been deleted.
# LA_T_6058119.flac file has been deleted.
# LA_T_4111857.flac file has been deleted.
# LA_T_2522205.flac file has been deleted.
# LA_T_8590705.flac file has been deleted.
# LA_T_1873366.flac file has been deleted.
# LA_T_1622807.flac file has been deleted.
# LA_T_1563365.flac file has been deleted.
# LA_T_1509895.flac file has been deleted.
# LA_T_6740492.flac file has been deleted.
# LA_T_5879219.flac file has been deleted.
# LA_T_4657357.flac file has been deleted.
# LA_T_4337007.flac file has been deleted.
# LA_T_6922879.flac file has been deleted.
# LA_T_6087132.flac file has been deleted.
# LA_T_1836557.flac file has been deleted.
# LA_T_7776792.flac file has been deleted.
# LA_T_8852458.flac file has been deleted.
# LA_T_2396357.flac file has been deleted.
# LA_T_5716018.flac file has been deleted.
# LA_T_3754513.flac file has been deleted.
# LA_T_4848180.flac file has been deleted.
# LA_T_8763090.flac file has been deleted.
# LA_T_5968030.flac file has been deleted.
# LA_T_1745690.flac file has been deleted.
# LA_T_1307755.flac file has been deleted.
# LA_T_4494495.flac file has been deleted.
# LA_T_7570086.flac file has been deleted.
# LA_T_4956486.flac file has been deleted.
# LA_T_8779336.flac file has been deleted.
# LA_T_8778911.flac file has been deleted.
# LA_T_5855384.flac file has been deleted.
# LA_T_9526930.flac file has been deleted.
# LA_T_9017338.flac file has been deleted.
# LA_T_3154434.flac file has been deleted.
# LA_T_1031233.flac file has been deleted.
# LA_T_5761909.flac file has been deleted.
# LA_T_3976536.flac file has been deleted.
# LA_T_7878810.flac file has been deleted.
# LA_T_6426400.flac file has been deleted.
# LA_T_6150186.flac file has been deleted.
# LA_T_3022241.flac file has been deleted.
# LA_T_5804164.flac file has been deleted.
# LA_T_2964864.flac file has been deleted.
# LA_T_2610237.flac file has been deleted.
# LA_T_8353042.flac file has been deleted.
# LA_T_2439075.flac file has been deleted.
# LA_T_3877261.flac file has been deleted.
# LA_T_2599380.flac file has been deleted.
# LA_T_6078944.flac file has been deleted.
# LA_T_6017674.flac file has been deleted.
# LA_T_1388480.flac file has been deleted.
# LA_T_5867902.flac file has been deleted.
# LA_T_9937911.flac file has been deleted.
# LA_T_7944475.flac file has been deleted.
# LA_T_9711174.flac file has been deleted.
# LA_T_4642415.flac file has been deleted.
# LA_T_5439881.flac file has been deleted.
# LA_T_5727134.flac file has been deleted.
# LA_T_3704574.flac file has been deleted.
# LA_T_7711596.flac file has been deleted.
# LA_T_8280464.flac file has been deleted.
# LA_T_1518499.flac file has been deleted.
# LA_T_9353442.flac file has been deleted.
# LA_T_1786825.flac file has been deleted.
# LA_T_3774973.flac file has been deleted.
# LA_T_6069460.flac file has been deleted.
# LA_T_7774011.flac file has been deleted.
# LA_T_2489865.flac file has been deleted.
# LA_T_6774071.flac file has been deleted.
# LA_T_1312618.flac file has been deleted.
# LA_T_7939168.flac file has been deleted.
# LA_T_8178089.flac file has been deleted.
# LA_T_8537108.flac file has been deleted.
# LA_T_6487011.flac file has been deleted.
# LA_T_7474358.flac file has been deleted.
# LA_T_5188464.flac file has been deleted.
# LA_T_3100997.flac file has been deleted.
# LA_T_3301728.flac file has been deleted.
# LA_T_3387982.flac file has been deleted.
# LA_T_6858608.flac file has been deleted.
# LA_T_9181552.flac file has been deleted.
# LA_T_1620551.flac file has been deleted.
# LA_T_1410416.flac file has been deleted.
# LA_T_6731739.flac file has been deleted.
# LA_T_6620806.flac file has been deleted.
# LA_T_5934685.flac file has been deleted.
# LA_T_5024980.flac file has been deleted.
# LA_T_4853062.flac file has been deleted.
# LA_T_9926593.flac file has been deleted.
# LA_T_6996135.flac file has been deleted.
# LA_T_7363698.flac file has been deleted.
# LA_T_4350897.flac file has been deleted.
# LA_T_5326363.flac file has been deleted.
# LA_T_9329650.flac file has been deleted.
# LA_T_8275432.flac file has been deleted.
# LA_T_6835345.flac file has been deleted.
# LA_T_8355506.flac file has been deleted.
# LA_T_3938480.flac file has been deleted.
# LA_T_2226656.flac file has been deleted.
# LA_T_1532340.flac file has been deleted.
# LA_T_1215743.flac file has been deleted.
# LA_T_2777160.flac file has been deleted.
# LA_T_6029472.flac file has been deleted.
# LA_T_4369654.flac file has been deleted.
# LA_T_8543938.flac file has been deleted.
# LA_T_6100680.flac file has been deleted.
# LA_T_6859654.flac file has been deleted.
# LA_T_2269650.flac file has been deleted.
# LA_T_1332868.flac file has been deleted.
# LA_T_4024715.flac file has been deleted.
# LA_T_6628237.flac file has been deleted.
# LA_T_6594586.flac file has been deleted.
# LA_T_7659619.flac file has been deleted.
# LA_T_4668575.flac file has been deleted.
# LA_T_7944618.flac file has been deleted.
# LA_T_1202598.flac file has been deleted.
# LA_T_2305882.flac file has been deleted.
# LA_T_4140135.flac file has been deleted.
# LA_T_4255653.flac file has been deleted.
# LA_T_3541528.flac file has been deleted.
# LA_T_1199930.flac file has been deleted.
# LA_T_6073321.flac file has been deleted.
# LA_T_5918833.flac file has been deleted.
# LA_T_1703395.flac file has been deleted.
# LA_T_1795259.flac file has been deleted.
# LA_T_8971567.flac file has been deleted.
# LA_T_4610869.flac file has been deleted.
# LA_T_3602602.flac file has been deleted.
# LA_T_3499323.flac file has been deleted.
# LA_T_9346943.flac file has been deleted.
# LA_T_5971038.flac file has been deleted.
# LA_T_5799348.flac file has been deleted.
# LA_T_5733848.flac file has been deleted.
# LA_T_1922746.flac file has been deleted.
# LA_T_6957393.flac file has been deleted.
# LA_T_1338417.flac file has been deleted.
# LA_T_4400269.flac file has been deleted.
# LA_T_7087021.flac file has been deleted.
# LA_T_2139401.flac file has been deleted.
# LA_T_4961493.flac file has been deleted.
# LA_T_6849040.flac file has been deleted.
# LA_T_8651978.flac file has been deleted.
# LA_T_3963536.flac file has been deleted.
# LA_T_8049822.flac file has been deleted.
# LA_T_2500033.flac file has been deleted.
# LA_T_8887502.flac file has been deleted.
# LA_T_2363469.flac file has been deleted.
# LA_T_6302089.flac file has been deleted.
# LA_T_5187822.flac file has been deleted.
# LA_T_2987671.flac file has been deleted.
# LA_T_4169604.flac file has been deleted.
# LA_T_7661468.flac file has been deleted.
# LA_T_9773629.flac file has been deleted.
# LA_T_6200206.flac file has been deleted.
# LA_T_4396533.flac file has been deleted.
# LA_T_6370865.flac file has been deleted.
# LA_T_3412575.flac file has been deleted.
# LA_T_7708952.flac file has been deleted.
# LA_T_5214235.flac file has been deleted.
# LA_T_9805478.flac file has been deleted.
# LA_T_1743583.flac file has been deleted.
# LA_T_7416513.flac file has been deleted.
# LA_T_5112094.flac file has been deleted.
# LA_T_6654102.flac file has been deleted.
# LA_T_9457505.flac file has been deleted.
# LA_T_7143060.flac file has been deleted.
# LA_T_7674329.flac file has been deleted.
# LA_T_2299372.flac file has been deleted.
# LA_T_4055913.flac file has been deleted.
# LA_T_5960681.flac file has been deleted.
# LA_T_5302452.flac file has been deleted.
# LA_T_5772566.flac file has been deleted.
# LA_T_1269847.flac file has been deleted.
# LA_T_7698914.flac file has been deleted.
# LA_T_7197738.flac file has been deleted.
# LA_T_6131759.flac file has been deleted.
# LA_T_7089601.flac file has been deleted.
# LA_T_3891170.flac file has been deleted.
# Total remaining in the folder 1000 The file exists.

# %%
import random

folder_path = './1' 

files = os.listdir(folder_path)

total_files = len(files)

# Number of files to delete
num_files_to_delete = 21800

files_to_delete = random.sample(files, min(num_files_to_delete, total_files))

for file_name in files_to_delete:
    file_path = os.path.join(folder_path, file_name)
    os.remove(file_path)

# %%
import os
import shutil

source_folders = ['0', '1']

# Name of the destination folder
target_folder = 'audio'

if not os.path.exists(target_folder):
    os.makedirs(target_folder)

for source_folder in source_folders:
    source_folder_path = os.path.join('.', source_folder)
    target_folder_path = os.path.join(target_folder, source_folder)

    # Check if there is a source folder
    if os.path.exists(source_folder_path):
        # Create destination folder
        if not os.path.exists(target_folder_path):
            os.makedirs(target_folder_path)

        # Move files from source folder to destination folder
        for file_name in os.listdir(source_folder_path):
            source_file_path = os.path.join(source_folder_path, file_name)
            target_file_path = os.path.join(target_folder_path, file_name)
            shutil.move(source_file_path, target_file_path)

print(f"The process is complete. '{target_folder}' folder contains the following files:")
print(os.listdir(target_folder))
# Out:
# The process is complete. 'audio' folder contains the following files:
# ['0', '1']

# %%
DATASET_PATH = "/coding projects/audio"
JSON_PATH = "data.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):

    
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        
        if dirpath is not dataset_path:

            
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            
            for f in filenames:

                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                
                for d in range(num_segments):

                    
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # Remove MFCC
                    mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)

    # Save MFCCs as json
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1485
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1347
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1566
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1139
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=663
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1474
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=539
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1616
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=674
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1492
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=535
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1419
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=515
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=637
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=481
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=552
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1476
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=492
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=472
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1490
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=604
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1450
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=571
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1523
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=441
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=669
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=603
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=531
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=541
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1489
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=589
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=523
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=490
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=590
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=568
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=448
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1556
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=607
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=960
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1698
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1639
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=232
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=105
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1381
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=936
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1213
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1453
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1572
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1550
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=632
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=170
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=665
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=131
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1332
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=50
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1379
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=688
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=2040
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=54
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=396
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1949
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=586
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=174
#   warnings.warn(

# %%
DATA_PATH = "/coding projects/audioforlstm/data.json"


def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validation_size):

    
    X, y = load_data(DATA_PATH)

    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):

    
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model


def predict(model, X, y):

    
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    
    prediction = model.predict(X)

    
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
if __name__ == "__main__":

    
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    
    
    input_shape = (130, 13, 1)
    model = build_model(input_shape)

    
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss', 
            verbose=1,
            patience=5,
            mode='min',
            restore_best_weights=True,
        )
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30,callbacks=[early_stopping],
)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 11, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 6, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 6, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 62, 4, 32)      │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 31, 2, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 31, 2, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 30, 1, 32)      │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 1, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 15, 1, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 480)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        30,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,994 (175.76 KB)
#  Trainable params: 44,802 (175.01 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 25s 97ms/step - accuracy: 0.5378 - loss: 1.1248 - val_accuracy: 0.5426 - val_loss: 1.0879
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6042 - loss: 0.8471 - val_accuracy: 0.6064 - val_loss: 0.7206
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6698 - loss: 0.6835 - val_accuracy: 0.6809 - val_loss: 0.6080
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7397 - loss: 0.5788 - val_accuracy: 0.7181 - val_loss: 0.5642
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8111 - loss: 0.4452 - val_accuracy: 0.7500 - val_loss: 0.5302
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8115 - loss: 0.4669 - val_accuracy: 0.7660 - val_loss: 0.5030
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8004 - loss: 0.4313 - val_accuracy: 0.7713 - val_loss: 0.5102
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8420 - loss: 0.3785 - val_accuracy: 0.7926 - val_loss: 0.4741
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8427 - loss: 0.3714 - val_accuracy: 0.8032 - val_loss: 0.4604
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8605 - loss: 0.3267 - val_accuracy: 0.8138 - val_loss: 0.4290
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8864 - loss: 0.3040 - val_accuracy: 0.8085 - val_loss: 0.4287
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8612 - loss: 0.3018 - val_accuracy: 0.8085 - val_loss: 0.4165
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9052 - loss: 0.2638 - val_accuracy: 0.8138 - val_loss: 0.4099
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8824 - loss: 0.2877 - val_accuracy: 0.8032 - val_loss: 0.4255
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9174 - loss: 0.2396 - val_accuracy: 0.8351 - val_loss: 0.3897
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9319 - loss: 0.2030 - val_accuracy: 0.8245 - val_loss: 0.3514
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9172 - loss: 0.2019 - val_accuracy: 0.8404 - val_loss: 0.3769
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9326 - loss: 0.2087 - val_accuracy: 0.8298 - val_loss: 0.3568
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.9221 - loss: 0.1986 - val_accuracy: 0.8511 - val_loss: 0.3301
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9283 - loss: 0.1987 - val_accuracy: 0.8404 - val_loss: 0.3349
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9374 - loss: 0.1856 - val_accuracy: 0.8457 - val_loss: 0.3165
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9373 - loss: 0.1638 - val_accuracy: 0.8457 - val_loss: 0.3137
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9495 - loss: 0.1612 - val_accuracy: 0.8723 - val_loss: 0.3056
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9516 - loss: 0.1545 - val_accuracy: 0.8670 - val_loss: 0.3004
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9398 - loss: 0.1609 - val_accuracy: 0.8298 - val_loss: 0.3242
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9537 - loss: 0.1367 - val_accuracy: 0.8457 - val_loss: 0.3095
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9500 - loss: 0.1269 - val_accuracy: 0.8564 - val_loss: 0.3036
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9666 - loss: 0.1256 - val_accuracy: 0.8670 - val_loss: 0.2888
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9763 - loss: 0.1199 - val_accuracy: 0.8511 - val_loss: 0.3031
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9630 - loss: 0.1180 - val_accuracy: 0.8777 - val_loss: 0.2919
# Restoring model weights from the end of the best epoch: 28.
# 10/10 - 0s - 15ms/step - accuracy: 0.8750 - loss: 0.2815
#
# Test accuracy: 0.875

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
from sklearn.metrics import classification_report

fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns for accuracy, loss, and confusion matrix

# Plot accuracy
axs[0].plot(history.history["accuracy"], label="Train")
axs[0].plot(history.history["val_accuracy"], label="Test")
axs[0].set_ylabel("Accuracy",fontsize=14)
axs[0].set_xlabel("Number of Epochs",fontsize=14)
axs[0].legend(loc="lower right",fontsize=12)
axs[0].set_title("Model Accuracy", fontsize=16)

# Plot loss
axs[1].plot(history.history["loss"], label="Train")
axs[1].plot(history.history["val_loss"], label="Test")
axs[1].set_ylabel("Loss", fontsize=14)
axs[1].set_xlabel("Number of Epochs",fontsize=14)
axs[1].legend(loc="upper right", fontsize=12)
axs[1].set_title("Model Loss", fontsize=16)

# Plot confusion matrix
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
loss = model.evaluate(X_train, y_train)
cf_matrix = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix, display_labels=['Fake', 'Real'])
disp.plot(ax=axs[2], cmap='Purples')
disp.ax_.set_title('Confusion Mtarix', fontsize=16, fontweight='medium')
disp.im_.colorbar.remove()
disp.ax_.set_xlabel('Predicted label', fontsize=14)
disp.ax_.set_ylabel('True label', fontsize=14)
disp.ax_.set_xticklabels(['Fake', 'Real'], fontsize=12)
disp.ax_.set_yticklabels(['Fake', 'Real'], fontsize=12)
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       154
#            1       0.85      0.92      0.88       158
#
#     accuracy                           0.88       312
#    macro avg       0.88      0.87      0.87       312
# weighted avg       0.88      0.88      0.87       312
#
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9903 - loss: 0.0839

# %%
# Save model
model.save("/coding projects/audioforlstm/cnn_audio.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf

# %%
def predict_voice(model, audio_file_path, genre_mapping):

    
    signal, sample_rate = librosa.load(audio_file_path, sr=22050)

    
    mfcc = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T

    # Appropriately size MFCCs
    mfcc = np.resize(mfcc, (130, 13, 1))

    # Reshape MFCCs are sized to the appropriate size
    mfcc = mfcc[np.newaxis, ...]

   
    prediction = model.predict(mfcc)
    predicted_index = np.argmax(prediction, axis=1)

    
    genre_label = genre_mapping[predicted_index[0]]
    print("Raw prediction:", prediction)

    return genre_label


model_path = "/coding projects/audioforlstm/cnn_audio.h5"
model = load_model(model_path)


audio_file_path = "/coding projects/asvspoof2019/LA/LA/ASVspoof2019_LA_train/flac/LA_T_1272637.flac"

genre_mapping = {0: "spoof", 1: "bonafide"}


predicted_voice = predict_voice(model, audio_file_path, genre_mapping)

print("Predicted label:", predicted_voice)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Raw prediction: [[0.00271803 0.9972819 ]]
# Predicted label: bonafide
